# %%
import numpy as np
import matplotlib.pyplot as plt

print("Jupyter is working!")

x = np.array([1, 2, 3, 4, 5])

print("Array:", x)
print("Mean:", x.mean())

plt.plot(x)
plt.show()
# Out:
# Jupyter is working!
# Array: [1 2 3 4 5]
# Mean: 3.0
